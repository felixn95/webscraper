# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import warnings
from DataProcessor import DataProcessor

warnings.simplefilter(action='ignore', category=FutureWarning)

preprocessor = DataProcessor()

# Assuming the data is loaded into a dataframe called df
df = preprocessor.process_nrw_data("06_16")

# Convert the timestamp to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Group by id, store_skuId, and store_storeId to find the number of stores per product variant
product_store_counts = df.groupby(['id', 'store_skuId'])['store_storeId'].nunique().reset_index()
product_store_counts = product_store_counts[product_store_counts['store_storeId'] >= 5]

# Filter the main dataframe to include only those product variants
df_filtered = df.merge(product_store_counts[['id', 'store_skuId']], on=['id', 'store_skuId'])

# Find stock out events
df_filtered['is_stock_out'] = (df_filtered['store_quantity'] == 0) & (df_filtered['store_quantity'].shift() > 0)

# Identify product variants with at least 2 stock out events in different stores
stock_out_events = df_filtered.groupby(['id', 'store_skuId', 'store_storeId'])['is_stock_out'].max().reset_index()
stock_out_counts = stock_out_events.groupby(['id', 'store_skuId'])['is_stock_out'].sum().reset_index()
stock_out_counts = stock_out_counts[stock_out_counts['is_stock_out'] >= 2]

# Further filter the dataframe to include only those variants
df_final = df_filtered.merge(stock_out_counts[['id', 'store_skuId']], on=['id', 'store_skuId'])

# Get a list of unique product variants to plot
product_variants_to_plot = df_final[['id', 'store_skuId', 'sub_category']].drop_duplicates()

# Debugging: Print the number of unique product variants identified
print(f"Number of unique product variants to plot: {len(product_variants_to_plot)}")

# Ensure the directory exists
output_directory = r'C:\Users\felix\Repos\decathlon_plots_marked_stock_outs'
os.makedirs(output_directory, exist_ok=True)

line_styles = ['-', '--', '-.', ':']
markers = ['o', 'v', '^', '<', '>', 's', 'p', '*', 'h', 'H', 'D', 'd', 'P', 'X']

for sub_category, group in product_variants_to_plot.groupby('sub_category'):
    count = 0
    for (product_id, store_skuId), product_group in group.groupby(['id', 'store_skuId']):
        if count >= 600:
            break
        product_data = df_final[(df_final['id'] == product_id) & (df_final['store_skuId'] == store_skuId)]
        
        # Debugging: Print the number of stores and the time range for each product variant
        num_stores = product_data['store_storeId'].nunique()
        time_range = product_data['timestamp'].min(), product_data['timestamp'].max()
        print(f"Plotting for product {product_id}, SKU {store_skuId}: {num_stores} stores, time range: {time_range}")

        plt.figure(figsize=(12, 8))
        for i, (store_id, store_group) in enumerate(product_data.groupby('store_storeId')):
            store_group = store_group.sort_values('timestamp')
            plt.plot(
                store_group['timestamp'], 
                store_group['store_quantity'], 
                label=store_group['store_storeName'].iloc[0],
                linestyle=line_styles[i % len(line_styles)],
                marker=markers[i % len(markers)]
            )
            plt.text(store_group['timestamp'].iloc[-1], store_group['store_quantity'].iloc[-1], store_group['store_storeName'].iloc[0])

            # Highlight stock out events
            stock_out_indices = store_group[(store_group['store_quantity'] == 0) & (store_group['store_quantity'].shift() > 0)].index
            plt.scatter(store_group.loc[stock_out_indices, 'timestamp'],
                        store_group.loc[stock_out_indices, 'store_quantity'],
                        edgecolor='black', facecolor='none', s=100, linewidth=1.5)

        plt.title(f"{product_data['product_name'].iloc[0]} - {sub_category} (price: {product_data['price'].iloc[0]})")
        plt.xlabel('Time')
        plt.ylabel('Quantity')
        plt.legend(loc='best')
        
        # Save the plot
        output_path = os.path.join(output_directory, f"{count}_{sub_category}_{product_id}_{store_skuId}.png")
        plt.savefig(output_path)
        plt.close()  # Close the figure to free memory
        
        count += 1
# Out:
# File already exists: processed_nrw_data/06_16_nrw_stock_data.csv. Loading DataFrame from file.
# Number of unique product variants to plot: 302
# Plotting for product 864538.0, SKU 4073788: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 864559.0, SKU 4073804: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 960034.0, SKU 4073894: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8492643.0, SKU 2558046: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8492643.0, SKU 4899198: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8492643.0, SKU 4899199: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8512943.0, SKU 2466767: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8576113.0, SKU 2963898: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8576113.0, SKU 4226754: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8603153.0, SKU 4129063: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8603728.0, SKU 4135920: 9 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8648928.0, SKU 4332301: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8750476.0, SKU 2558045: 9 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8750484.0, SKU 4665130: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8750555.0, SKU 2961624: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8750560.0, SKU 4665791: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8750565.0, SKU 4665796: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8759981.0, SKU 4579105: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8767220.0, SKU 4663536: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8794274.0, SKU 4838470: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8834454.0, SKU 5015653: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8834461.0, SKU 5015677: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8852990.0, SKU 2918996: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8852993.0, SKU 2961595: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8852994.0, SKU 2970405: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8852994.0, SKU 5075747: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8852997.0, SKU 5075750: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8852999.0, SKU 2962551: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8852999.0, SKU 5075752: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8853003.0, SKU 2962513: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8853003.0, SKU 5075814: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8853007.0, SKU 5075837: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8853029.0, SKU 5075886: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 8881982.0, SKU 5204934: 12 stores, time range: (Timestamp('2024-05-14 19:54:41.567973'), Timestamp('2024-06-14 18:40:59.516664'))
# Plotting for product 25504539.0, SKU 3fd436ff-a08c-48fb-b74d-ac1c6ff6289b: 12 stores, time range: (Timestamp('2024-05-14 19:58:06.350256'), Timestamp('2024-06-14 18:39:44.788891'))
# Plotting for product 8400336.0, SKU 2369309: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8400336.0, SKU 2369312: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8400336.0, SKU 2369315: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8400336.0, SKU 2369317: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8405317.0, SKU 2392637: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8502354.0, SKU 2496977: 12 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8502354.0, SKU 2496981: 12 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8526892.0, SKU 2652460: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8526892.0, SKU 2652461: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8526895.0, SKU 2652466: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8526895.0, SKU 2652467: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8526895.0, SKU 4855831: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8548195.0, SKU 2692818: 12 stores, time range: (Timestamp('2024-05-10 21:29:16.284221'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8548195.0, SKU 2692819: 12 stores, time range: (Timestamp('2024-05-10 21:29:16.284221'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8554167.0, SKU 2762034: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-12 10:48:17.425856'))
# Plotting for product 8555876.0, SKU 2940923: 12 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8555876.0, SKU 2940924: 12 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8555876.0, SKU 2940925: 12 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8555876.0, SKU 2940926: 12 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8561304.0, SKU 2896692: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-12 10:44:36.411229'))
# Plotting for product 8561304.0, SKU 2896694: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-12 10:44:36.411229'))
# Plotting for product 8577925.0, SKU 2978743: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-11 23:46:00.541858'))
# Plotting for product 8577925.0, SKU 2978745: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-11 23:46:00.541858'))
# Plotting for product 8577925.0, SKU 2978746: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-11 23:46:00.541858'))
# Plotting for product 8586865.0, SKU 4030297: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:36:43.961152'))
# Plotting for product 8586865.0, SKU 4030298: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:36:43.961152'))
# Plotting for product 8606765.0, SKU 4174802: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8606778.0, SKU 4174807: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-10 21:56:21.111489'))
# Plotting for product 8606778.0, SKU 4174817: 11 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-23 00:17:50.461165'))
# Plotting for product 8608513.0, SKU 4172068: 10 stores, time range: (Timestamp('2024-05-12 10:41:00.690241'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8608513.0, SKU 4216660: 10 stores, time range: (Timestamp('2024-05-12 10:41:00.690241'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8608513.0, SKU 4216789: 10 stores, time range: (Timestamp('2024-05-12 10:41:00.690241'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8649307.0, SKU 4335090: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8653527.0, SKU 4357005: 11 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8653527.0, SKU 4357006: 11 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8653527.0, SKU 4357007: 11 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8653543.0, SKU 4357024: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8653543.0, SKU 4357028: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8653545.0, SKU 4357058: 10 stores, time range: (Timestamp('2024-05-12 10:41:00.690241'), Timestamp('2024-05-23 00:07:38.534934'))
# Plotting for product 8653545.0, SKU 4357059: 10 stores, time range: (Timestamp('2024-05-12 10:41:00.690241'), Timestamp('2024-05-23 00:07:38.534934'))
# Plotting for product 8653665.0, SKU 4357661: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8654920.0, SKU 4358544: 11 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-23 00:17:50.461165'))
# Plotting for product 8654920.0, SKU 4358546: 11 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-23 00:17:50.461165'))
# Plotting for product 8654920.0, SKU 4358547: 11 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-23 00:17:50.461165'))
# Plotting for product 8655166.0, SKU 4359309: 11 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8655166.0, SKU 4359310: 11 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8667970.0, SKU 4031483: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8667970.0, SKU 4031484: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8667970.0, SKU 4416012: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8667970.0, SKU 4416015: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8667970.0, SKU 4416020: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8667970.0, SKU 4416021: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8732272.0, SKU 4465400: 12 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8732272.0, SKU 4465403: 12 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8732272.0, SKU 5165164: 12 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8753457.0, SKU 4653068: 10 stores, time range: (Timestamp('2024-05-09 00:41:54.563027'), Timestamp('2024-05-13 19:36:43.961152'))
# Plotting for product 8773290.0, SKU 4712638: 11 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:40:23.200926'))
# Plotting for product 8872755.0, SKU 4465403: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8872755.0, SKU 5165161: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8872755.0, SKU 5165164: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8378612.0, SKU 2166412: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8378612.0, SKU 2961174: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8378612.0, SKU 2961177: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8378612.0, SKU 2961179: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8378612.0, SKU 2961180: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8378612.0, SKU 2961182: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8400336.0, SKU 2369309: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8400336.0, SKU 2369312: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8400336.0, SKU 2369315: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8400336.0, SKU 2369317: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8502354.0, SKU 2496977: 12 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8502354.0, SKU 2496981: 12 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8526892.0, SKU 2652460: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8526892.0, SKU 2652461: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8526893.0, SKU 2652463: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8526893.0, SKU 2652464: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8526895.0, SKU 2652466: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8526895.0, SKU 2652467: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8526895.0, SKU 4855831: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8545836.0, SKU 2685541: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8545836.0, SKU 4241336: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8548195.0, SKU 2692818: 12 stores, time range: (Timestamp('2024-05-10 21:29:16.284221'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8548195.0, SKU 2692819: 12 stores, time range: (Timestamp('2024-05-10 21:29:16.284221'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8549669.0, SKU 2757208: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8549669.0, SKU 2757209: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8549669.0, SKU 2757210: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8549669.0, SKU 2757212: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8549669.0, SKU 4630011: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8550383.0, SKU 4630049: 12 stores, time range: (Timestamp('2024-05-13 18:00:08.903906'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8550383.0, SKU 4630050: 12 stores, time range: (Timestamp('2024-05-13 18:00:08.903906'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8555876.0, SKU 2940923: 12 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8555876.0, SKU 2940924: 12 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8555876.0, SKU 2940925: 12 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8555876.0, SKU 2940926: 12 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8561304.0, SKU 2896692: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-12 10:44:36.411229'))
# Plotting for product 8561304.0, SKU 2896694: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-12 10:44:36.411229'))
# Plotting for product 8575681.0, SKU 2166412: 10 stores, time range: (Timestamp('2024-05-22 23:48:35.746100'), Timestamp('2024-05-23 00:17:50.461165'))
# Plotting for product 8575681.0, SKU 2961180: 10 stores, time range: (Timestamp('2024-05-22 23:48:35.746100'), Timestamp('2024-05-23 00:17:50.461165'))
# Plotting for product 8575681.0, SKU 2961182: 10 stores, time range: (Timestamp('2024-05-22 23:48:35.746100'), Timestamp('2024-05-23 00:17:50.461165'))
# Plotting for product 8575940.0, SKU 2962860: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8575940.0, SKU 2962863: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8575940.0, SKU 2962864: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8600059.0, SKU 4227696: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8600059.0, SKU 4227697: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8602020.0, SKU 4116099: 12 stores, time range: (Timestamp('2024-05-10 20:10:39.427745'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8602020.0, SKU 4116100: 12 stores, time range: (Timestamp('2024-05-10 20:10:39.427745'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8602020.0, SKU 4116101: 12 stores, time range: (Timestamp('2024-05-10 20:10:39.427745'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8602020.0, SKU 4116102: 12 stores, time range: (Timestamp('2024-05-10 20:10:39.427745'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8602020.0, SKU 4266483: 12 stores, time range: (Timestamp('2024-05-10 20:10:39.427745'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8602020.0, SKU 4266485: 12 stores, time range: (Timestamp('2024-05-10 20:10:39.427745'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8602020.0, SKU 4266486: 12 stores, time range: (Timestamp('2024-05-10 20:10:39.427745'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8606778.0, SKU 4174817: 11 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-23 00:17:50.461165'))
# Plotting for product 8640691.0, SKU 4116099: 10 stores, time range: (Timestamp('2024-05-22 23:48:35.746100'), Timestamp('2024-05-23 00:17:50.461165'))
# Plotting for product 8640691.0, SKU 4116102: 10 stores, time range: (Timestamp('2024-05-22 23:48:35.746100'), Timestamp('2024-05-23 00:17:50.461165'))
# Plotting for product 8640691.0, SKU 4266483: 10 stores, time range: (Timestamp('2024-05-22 23:48:35.746100'), Timestamp('2024-05-23 00:17:50.461165'))
# Plotting for product 8640691.0, SKU 4266486: 10 stores, time range: (Timestamp('2024-05-22 23:48:35.746100'), Timestamp('2024-05-23 00:17:50.461165'))
# Plotting for product 8649307.0, SKU 4335090: 10 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-13 19:39:16.944094'))
# Plotting for product 8649387.0, SKU 4335305: 10 stores, time range: (Timestamp('2024-05-22 23:48:35.746100'), Timestamp('2024-05-23 00:17:50.461165'))
# Plotting for product 8653527.0, SKU 4357005: 11 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8653527.0, SKU 4357006: 11 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8653527.0, SKU 4357007: 11 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8653537.0, SKU 4357014: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8653537.0, SKU 4357016: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8653545.0, SKU 4357058: 10 stores, time range: (Timestamp('2024-05-12 10:41:00.690241'), Timestamp('2024-05-23 00:07:38.534934'))
# Plotting for product 8653545.0, SKU 4357059: 10 stores, time range: (Timestamp('2024-05-12 10:41:00.690241'), Timestamp('2024-05-23 00:07:38.534934'))
# Plotting for product 8654920.0, SKU 4358544: 11 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-23 00:17:50.461165'))
# Plotting for product 8654920.0, SKU 4358546: 11 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-23 00:17:50.461165'))
# Plotting for product 8654920.0, SKU 4358547: 11 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-05-23 00:17:50.461165'))
# Plotting for product 8655166.0, SKU 4359309: 11 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8655166.0, SKU 4359310: 11 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8655220.0, SKU 4359394: 10 stores, time range: (Timestamp('2024-05-22 23:48:35.746100'), Timestamp('2024-05-23 00:17:50.461165'))
# Plotting for product 8664452.0, SKU 4429398: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8664452.0, SKU 4855832: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8732272.0, SKU 4465400: 12 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8732272.0, SKU 4465403: 12 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8732272.0, SKU 5165164: 12 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8732637.0, SKU 4468654: 11 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:40:23.200926'))
# Plotting for product 8732637.0, SKU 4468656: 11 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:40:23.200926'))
# Plotting for product 8732637.0, SKU 4468657: 11 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:40:23.200926'))
# Plotting for product 8758087.0, SKU 4569700: 11 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:37:50.688703'))
# Plotting for product 8758087.0, SKU 4569701: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8773290.0, SKU 4712638: 11 stores, time range: (Timestamp('2024-05-09 00:38:23.113166'), Timestamp('2024-06-14 19:40:23.200926'))
# Plotting for product 8826512.0, SKU 4977360: 12 stores, time range: (Timestamp('2024-05-10 20:04:18.367934'), Timestamp('2024-06-14 19:42:54.120733'))
# Plotting for product 8826512.0, SKU 4977362: 10 stores, time range: (Timestamp('2024-05-22 23:48:35.746100'), Timestamp('2024-05-23 00:17:50.461165'))
# Plotting for product 9.0, SKU ef8ab573-810a-41bb-beaa-972c6e162043: 12 stores, time range: (Timestamp('2024-05-10 18:57:32.676129'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 22.0, SKU 220bdc2e-0635-4923-a529-7fb9d6c51743: 12 stores, time range: (Timestamp('2024-05-10 19:02:19.139821'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 22.0, SKU 606d8a1c-799f-498d-8483-9423e9f28bb3: 12 stores, time range: (Timestamp('2024-05-10 19:02:19.139821'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 22.0, SKU a119601a-b801-41dd-ae89-c6cbe30a5099: 12 stores, time range: (Timestamp('2024-05-10 19:02:19.139821'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 22.0, SKU d39991c9-7875-4315-a6bb-29b821bd40a0: 12 stores, time range: (Timestamp('2024-05-10 19:02:19.139821'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 48.0, SKU 87fbc97d-f213-4ed0-80e1-5e37be37f389: 10 stores, time range: (Timestamp('2024-05-10 18:57:32.676129'), Timestamp('2024-06-14 19:10:01.589791'))
# Plotting for product 1903.0, SKU ea64ce49-b861-4e5e-a418-617dc756d229: 12 stores, time range: (Timestamp('2024-05-22 23:13:04.479907'), Timestamp('2024-05-22 23:46:35.099568'))
# Plotting for product 4272.0, SKU ec9c0f41-b75a-4042-ad0b-3362a6113a51: 5 stores, time range: (Timestamp('2024-05-14 21:22:28.117207'), Timestamp('2024-06-14 19:10:01.589791'))
# Plotting for product 6150.0, SKU 92761422-f8c9-46aa-8d15-c508f5514435: 12 stores, time range: (Timestamp('2024-05-14 21:19:42.835897'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8336573.0, SKU 712792: 12 stores, time range: (Timestamp('2024-05-10 18:57:32.676129'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8354819.0, SKU 2017323: 12 stores, time range: (Timestamp('2024-05-14 21:19:42.835897'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8361558.0, SKU 2052983: 12 stores, time range: (Timestamp('2024-05-10 18:57:32.676129'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8484134.0, SKU 2526815: 12 stores, time range: (Timestamp('2024-05-10 18:57:32.676129'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8491911.0, SKU 2524939: 12 stores, time range: (Timestamp('2024-05-11 20:42:46.852252'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8491912.0, SKU 2524940: 5 stores, time range: (Timestamp('2024-05-22 23:15:51.742598'), Timestamp('2024-05-22 23:46:35.099568'))
# Plotting for product 8501452.0, SKU 2491923: 12 stores, time range: (Timestamp('2024-05-10 18:57:32.676129'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8529877.0, SKU 2667751: 5 stores, time range: (Timestamp('2024-05-22 23:15:51.742598'), Timestamp('2024-05-22 23:46:35.099568'))
# Plotting for product 8542707.0, SKU 2711064: 12 stores, time range: (Timestamp('2024-05-10 18:57:32.676129'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8588490.0, SKU 4044804: 12 stores, time range: (Timestamp('2024-05-11 20:41:13.492711'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8603283.0, SKU 4132392: 12 stores, time range: (Timestamp('2024-05-14 21:22:28.117207'), Timestamp('2024-06-14 19:10:01.589791'))
# Plotting for product 8607943.0, SKU 4169366: 12 stores, time range: (Timestamp('2024-05-14 21:19:42.835897'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8607943.0, SKU 4834090: 12 stores, time range: (Timestamp('2024-05-14 21:19:42.835897'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8607949.0, SKU 4169387: 12 stores, time range: (Timestamp('2024-05-14 21:19:42.835897'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8616804.0, SKU 4224992: 12 stores, time range: (Timestamp('2024-05-14 21:19:42.835897'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8651249.0, SKU 4343616: 12 stores, time range: (Timestamp('2024-05-14 21:19:42.835897'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8651249.0, SKU 4343617: 12 stores, time range: (Timestamp('2024-05-14 21:19:42.835897'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8651249.0, SKU 4343618: 12 stores, time range: (Timestamp('2024-05-14 21:19:42.835897'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8651539.0, SKU 4345075: 12 stores, time range: (Timestamp('2024-05-10 18:57:32.676129'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8666894.0, SKU 4367777: 12 stores, time range: (Timestamp('2024-05-10 18:57:32.676129'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8751180.0, SKU 4581752: 12 stores, time range: (Timestamp('2024-05-10 18:57:32.676129'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8766093.0, SKU 4660463: 12 stores, time range: (Timestamp('2024-05-10 18:57:32.676129'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8766094.0, SKU 4660465: 12 stores, time range: (Timestamp('2024-05-14 21:19:42.835897'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8786091.0, SKU 4771991: 12 stores, time range: (Timestamp('2024-05-10 19:02:19.139821'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8796623.0, SKU 4834090: 5 stores, time range: (Timestamp('2024-05-22 23:15:51.742598'), Timestamp('2024-05-22 23:46:35.099568'))
# Plotting for product 8816726.0, SKU 4934747: 12 stores, time range: (Timestamp('2024-05-10 18:57:32.676129'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8825899.0, SKU 4978723: 12 stores, time range: (Timestamp('2024-05-14 21:19:42.835897'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8841907.0, SKU 5006808: 6 stores, time range: (Timestamp('2024-05-22 23:24:33.736776'), Timestamp('2024-05-22 23:43:42.210672'))
# Plotting for product 8841907.0, SKU 5006809: 6 stores, time range: (Timestamp('2024-05-22 23:24:33.736776'), Timestamp('2024-05-22 23:43:42.210672'))
# Plotting for product 8843539.0, SKU 2528920: 7 stores, time range: (Timestamp('2024-05-22 23:13:04.479907'), Timestamp('2024-05-22 23:43:42.210672'))
# Plotting for product 8843539.0, SKU 4779847: 7 stores, time range: (Timestamp('2024-05-22 23:13:04.479907'), Timestamp('2024-05-22 23:43:42.210672'))
# Plotting for product 8843539.0, SKU 5035844: 7 stores, time range: (Timestamp('2024-05-22 23:13:04.479907'), Timestamp('2024-05-22 23:43:42.210672'))
# Plotting for product 8851735.0, SKU 5057389: 12 stores, time range: (Timestamp('2024-05-14 21:19:42.835897'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8902450.0, SKU 5306794: 12 stores, time range: (Timestamp('2024-05-10 19:02:19.139821'), Timestamp('2024-06-14 19:12:35.321317'))
# Plotting for product 8207355.0, SKU 1478489: 7 stores, time range: (Timestamp('2024-05-14 19:25:28.200071'), Timestamp('2024-06-14 18:26:17.539179'))
# Plotting for product 8493329.0, SKU 2562459: 7 stores, time range: (Timestamp('2024-05-14 19:25:28.200071'), Timestamp('2024-06-14 18:26:17.539179'))
# Plotting for product 8493330.0, SKU 2562460: 7 stores, time range: (Timestamp('2024-05-14 19:25:28.200071'), Timestamp('2024-06-14 18:26:17.539179'))
# Plotting for product 8504347.0, SKU 2480082: 12 stores, time range: (Timestamp('2024-05-14 19:11:42.729867'), Timestamp('2024-06-14 18:26:17.539179'))
# Plotting for product 8549674.0, SKU 2757221: 12 stores, time range: (Timestamp('2024-05-14 19:11:42.729867'), Timestamp('2024-06-14 18:26:17.539179'))
# Plotting for product 8560509.0, SKU 2899945: 12 stores, time range: (Timestamp('2024-05-14 19:11:42.729867'), Timestamp('2024-06-14 18:26:17.539179'))
# Plotting for product 8560510.0, SKU 2899945: 10 stores, time range: (Timestamp('2024-05-22 21:30:50.360677'), Timestamp('2024-05-22 21:58:19.889405'))
# Plotting for product 8572258.0, SKU 2957211: 12 stores, time range: (Timestamp('2024-05-14 19:11:42.729867'), Timestamp('2024-06-14 18:26:17.539179'))
# Plotting for product 8575761.0, SKU 2961507: 12 stores, time range: (Timestamp('2024-05-14 19:11:42.729867'), Timestamp('2024-06-14 18:26:17.539179'))
# Plotting for product 8576761.0, SKU 2969094: 12 stores, time range: (Timestamp('2024-05-14 19:11:42.729867'), Timestamp('2024-06-14 18:26:17.539179'))
# Plotting for product 8582112.0, SKU 4008538: 12 stores, time range: (Timestamp('2024-05-14 19:11:42.729867'), Timestamp('2024-06-14 18:26:17.539179'))
# Plotting for product 8606450.0, SKU 4181596: 12 stores, time range: (Timestamp('2024-05-14 19:11:42.729867'), Timestamp('2024-06-14 18:26:17.539179'))
# Plotting for product 8612535.0, SKU 4197017: 9 stores, time range: (Timestamp('2024-05-14 19:11:42.729867'), Timestamp('2024-06-14 18:25:12.510236'))
# Plotting for product 8612535.0, SKU 4197018: 9 stores, time range: (Timestamp('2024-05-14 19:11:42.729867'), Timestamp('2024-06-14 18:25:12.510236'))
# Plotting for product 8612537.0, SKU 4197018: 5 stores, time range: (Timestamp('2024-05-22 21:30:50.360677'), Timestamp('2024-05-22 21:46:16.560267'))
# Plotting for product 8618607.0, SKU 4810167: 12 stores, time range: (Timestamp('2024-05-14 19:11:42.729867'), Timestamp('2024-06-14 18:26:17.539179'))
# Plotting for product 8640745.0, SKU 4266695: 12 stores, time range: (Timestamp('2024-05-14 19:11:42.729867'), Timestamp('2024-06-14 18:26:17.539179'))
# Plotting for product 8641352.0, SKU 4269987: 11 stores, time range: (Timestamp('2024-05-14 19:11:42.729867'), Timestamp('2024-06-14 18:25:12.510236'))
# Plotting for product 8676217.0, SKU 4451121: 12 stores, time range: (Timestamp('2024-05-14 19:11:42.729867'), Timestamp('2024-06-14 18:26:17.539179'))
# Plotting for product 8676223.0, SKU 4451134: 11 stores, time range: (Timestamp('2024-05-14 19:11:42.729867'), Timestamp('2024-06-14 18:25:12.510236'))
# Plotting for product 8676226.0, SKU 4451137: 10 stores, time range: (Timestamp('2024-05-22 21:30:50.360677'), Timestamp('2024-05-22 21:58:19.889405'))
# Plotting for product 8750657.0, SKU 4666128: 10 stores, time range: (Timestamp('2024-05-22 21:30:50.360677'), Timestamp('2024-05-22 21:58:19.889405'))
# Plotting for product 8750779.0, SKU 4666499: 12 stores, time range: (Timestamp('2024-05-14 19:11:42.729867'), Timestamp('2024-06-14 18:26:17.539179'))
# Plotting for product 8756891.0, SKU 4544149: 12 stores, time range: (Timestamp('2024-05-14 19:11:42.729867'), Timestamp('2024-06-14 18:26:17.539179'))
# Plotting for product 8789851.0, SKU 4785695: 12 stores, time range: (Timestamp('2024-05-14 19:11:42.729867'), Timestamp('2024-06-14 18:26:17.539179'))
# Plotting for product 8789851.0, SKU 5066131: 12 stores, time range: (Timestamp('2024-05-14 19:11:42.729867'), Timestamp('2024-06-14 18:26:17.539179'))
# Plotting for product 8821021.0, SKU 4954907: 11 stores, time range: (Timestamp('2024-05-14 19:11:42.729867'), Timestamp('2024-06-14 18:25:12.510236'))
# Plotting for product 8834488.0, SKU 5015779: 11 stores, time range: (Timestamp('2024-05-14 19:11:42.729867'), Timestamp('2024-06-14 18:25:12.510236'))
# Plotting for product 8844625.0, SKU 5046038: 12 stores, time range: (Timestamp('2024-05-14 19:11:42.729867'), Timestamp('2024-06-14 18:26:17.539179'))
# Plotting for product 8543065.0, SKU 2705922: 7 stores, time range: (Timestamp('2024-05-14 20:38:45.632787'), Timestamp('2024-06-14 18:57:02.314001'))
# Plotting for product 8575620.0, SKU 2960898: 12 stores, time range: (Timestamp('2024-05-14 20:38:45.632787'), Timestamp('2024-06-14 18:57:02.314001'))
# Plotting for product 8575966.0, SKU 2963002: 12 stores, time range: (Timestamp('2024-05-14 20:38:45.632787'), Timestamp('2024-06-14 18:57:02.314001'))
# Plotting for product 8575966.0, SKU 2963004: 12 stores, time range: (Timestamp('2024-05-14 20:38:45.632787'), Timestamp('2024-06-14 18:57:02.314001'))
# Plotting for product 8575966.0, SKU 2963005: 12 stores, time range: (Timestamp('2024-05-14 20:38:45.632787'), Timestamp('2024-06-14 18:57:02.314001'))
# Plotting for product 8575969.0, SKU 2963016: 12 stores, time range: (Timestamp('2024-05-14 20:42:22.219298'), Timestamp('2024-06-14 18:54:25.193545'))
# Plotting for product 8575969.0, SKU 2963017: 12 stores, time range: (Timestamp('2024-05-14 20:42:22.219298'), Timestamp('2024-06-14 18:54:25.193545'))
# Plotting for product 8582047.0, SKU 4008303: 12 stores, time range: (Timestamp('2024-05-14 20:38:45.632787'), Timestamp('2024-06-14 18:57:02.314001'))
# Plotting for product 8584370.0, SKU 4017486: 12 stores, time range: (Timestamp('2024-05-14 20:38:45.632787'), Timestamp('2024-06-14 18:57:02.314001'))
# Plotting for product 8584388.0, SKU 4017515: 7 stores, time range: (Timestamp('2024-05-14 20:38:45.632787'), Timestamp('2024-06-14 18:57:02.314001'))
# Plotting for product 8595949.0, SKU 2923834: 12 stores, time range: (Timestamp('2024-05-14 20:38:45.632787'), Timestamp('2024-06-14 18:57:02.314001'))
# Plotting for product 8612277.0, SKU 2566909: 12 stores, time range: (Timestamp('2024-05-14 20:38:45.632787'), Timestamp('2024-06-14 18:57:02.314001'))
# Plotting for product 8612374.0, SKU 4195608: 12 stores, time range: (Timestamp('2024-05-14 20:42:22.219298'), Timestamp('2024-06-14 18:54:25.193545'))
# Plotting for product 8648438.0, SKU 2460957: 12 stores, time range: (Timestamp('2024-05-14 20:38:45.632787'), Timestamp('2024-06-14 18:57:02.314001'))
# Plotting for product 8648442.0, SKU 4327544: 12 stores, time range: (Timestamp('2024-05-14 20:38:45.632787'), Timestamp('2024-06-14 18:57:02.314001'))
# Plotting for product 8648442.0, SKU 5145351: 12 stores, time range: (Timestamp('2024-05-14 20:38:45.632787'), Timestamp('2024-06-14 18:57:02.314001'))
# Plotting for product 8733136.0, SKU 4474078: 12 stores, time range: (Timestamp('2024-05-14 20:38:45.632787'), Timestamp('2024-06-14 18:57:02.314001'))
# Plotting for product 8737675.0, SKU 4518516: 12 stores, time range: (Timestamp('2024-05-14 20:38:45.632787'), Timestamp('2024-06-14 18:57:02.314001'))
# Plotting for product 8737676.0, SKU 4518516: 12 stores, time range: (Timestamp('2024-05-22 22:36:52.224677'), Timestamp('2024-05-22 23:10:23.766974'))
# Plotting for product 8784662.0, SKU 4802672: 8 stores, time range: (Timestamp('2024-05-14 20:42:22.219298'), Timestamp('2024-06-14 18:54:25.193545'))
# Plotting for product 8799899.0, SKU 4844287: 12 stores, time range: (Timestamp('2024-05-14 20:38:45.632787'), Timestamp('2024-06-14 18:57:02.314001'))
# Plotting for product 8799901.0, SKU 4844297: 12 stores, time range: (Timestamp('2024-05-14 20:38:45.632787'), Timestamp('2024-06-14 18:57:02.314001'))
# Plotting for product 8799901.0, SKU 4844299: 12 stores, time range: (Timestamp('2024-05-14 20:38:45.632787'), Timestamp('2024-06-14 18:57:02.314001'))
# Plotting for product 8799903.0, SKU 4844317: 5 stores, time range: (Timestamp('2024-05-14 20:42:22.219298'), Timestamp('2024-06-14 18:54:25.193545'))
# Plotting for product 8810976.0, SKU 4899450: 12 stores, time range: (Timestamp('2024-05-14 20:38:45.632787'), Timestamp('2024-06-14 18:57:02.314001'))
# Plotting for product 8827568.0, SKU 4966682: 12 stores, time range: (Timestamp('2024-05-14 20:38:45.632787'), Timestamp('2024-06-14 18:57:02.314001'))
# Plotting for product 8833323.0, SKU 5008150: 10 stores, time range: (Timestamp('2024-05-14 20:38:45.632787'), Timestamp('2024-06-14 18:57:02.314001'))
# Plotting for product 8841743.0, SKU 5006373: 12 stores, time range: (Timestamp('2024-05-14 20:38:45.632787'), Timestamp('2024-06-14 18:57:02.314001'))
# Plotting for product 8901525.0, SKU 2705854: 12 stores, time range: (Timestamp('2024-05-14 20:38:45.632787'), Timestamp('2024-06-14 18:57:02.314001'))
# Plotting for product 8901525.0, SKU 5284409: 12 stores, time range: (Timestamp('2024-05-14 20:38:45.632787'), Timestamp('2024-06-14 18:57:02.314001'))
# Plotting for product 8492687.0, SKU 2558275: 12 stores, time range: (Timestamp('2024-05-10 18:16:51.728974'), Timestamp('2024-06-14 18:12:32.194520'))
# Plotting for product 8501684.0, SKU 2490906: 11 stores, time range: (Timestamp('2024-05-14 18:32:44.365334'), Timestamp('2024-06-14 18:12:32.194520'))
# Plotting for product 8553542.0, SKU 2758193: 12 stores, time range: (Timestamp('2024-05-10 18:18:25.647968'), Timestamp('2024-06-14 18:12:32.194520'))
# Plotting for product 8554912.0, SKU 2755985: 12 stores, time range: (Timestamp('2024-05-14 18:32:44.365334'), Timestamp('2024-06-14 18:12:32.194520'))
# Plotting for product 8562098.0, SKU 2881865: 11 stores, time range: (Timestamp('2024-05-14 18:32:44.365334'), Timestamp('2024-06-14 18:12:32.194520'))
# Plotting for product 8576043.0, SKU 2963443: 12 stores, time range: (Timestamp('2024-05-14 18:32:44.365334'), Timestamp('2024-06-14 18:12:32.194520'))
# Plotting for product 8576112.0, SKU 2963896: 12 stores, time range: (Timestamp('2024-05-10 18:18:25.647968'), Timestamp('2024-06-14 18:12:32.194520'))
# Plotting for product 8578470.0, SKU 2983015: 11 stores, time range: (Timestamp('2024-05-14 18:32:44.365334'), Timestamp('2024-06-14 18:12:32.194520'))
# Plotting for product 8584545.0, SKU 4018190: 12 stores, time range: (Timestamp('2024-05-14 18:32:44.365334'), Timestamp('2024-06-14 18:12:32.194520'))
# Plotting for product 8642422.0, SKU 4274620: 12 stores, time range: (Timestamp('2024-05-10 18:16:51.728974'), Timestamp('2024-06-14 18:12:32.194520'))
# Plotting for product 8648383.0, SKU 4327058: 12 stores, time range: (Timestamp('2024-05-10 18:16:51.728974'), Timestamp('2024-06-14 18:12:32.194520'))
# Plotting for product 8734596.0, SKU 4490211: 12 stores, time range: (Timestamp('2024-05-10 18:16:51.728974'), Timestamp('2024-06-14 18:12:32.194520'))
# Plotting for product 8739042.0, SKU 4533199: 6 stores, time range: (Timestamp('2024-05-22 20:56:40.685718'), Timestamp('2024-05-22 21:25:11.339211'))
# Plotting for product 8739048.0, SKU 4533319: 12 stores, time range: (Timestamp('2024-05-14 18:32:44.365334'), Timestamp('2024-06-14 18:12:32.194520'))
# Plotting for product 8755590.0, SKU 4557070: 12 stores, time range: (Timestamp('2024-05-10 18:16:51.728974'), Timestamp('2024-06-14 18:12:32.194520'))
# Plotting for product 8755593.0, SKU 4557078: 12 stores, time range: (Timestamp('2024-05-22 20:56:40.685718'), Timestamp('2024-05-22 21:28:08.168362'))
# Plotting for product 8788265.0, SKU 4782139: 12 stores, time range: (Timestamp('2024-05-22 20:56:40.685718'), Timestamp('2024-05-22 21:28:08.168362'))
# Plotting for product 8810920.0, SKU 4899305: 12 stores, time range: (Timestamp('2024-05-14 18:32:44.365334'), Timestamp('2024-06-14 18:12:32.194520'))
# Plotting for product 8810951.0, SKU 2380420: 12 stores, time range: (Timestamp('2024-05-10 18:16:51.728974'), Timestamp('2024-06-14 18:12:32.194520'))
# Plotting for product 8810951.0, SKU 4899358: 12 stores, time range: (Timestamp('2024-05-10 18:16:51.728974'), Timestamp('2024-06-14 18:12:32.194520'))
# Plotting for product 8844621.0, SKU 5046025: 12 stores, time range: (Timestamp('2024-05-14 18:32:44.365334'), Timestamp('2024-06-14 18:12:32.194520'))
